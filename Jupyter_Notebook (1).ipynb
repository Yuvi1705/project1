# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook On IBM Watson Studio

# %% [markdown]
# M.YUVARAAJ
# DATA SCIENTIST

# %% [markdown]
# I AM INTRESTED IN DATA SCIENCE SINCE IT SUITS MY SKILLS AND MY MINDSET OF HOW A JOB SHOULD BE AND OBVIOUSLY IT IS ALSO OBE OF THE HIGHLY PAID JOBS AROUND THE WORLD.

# %% [markdown]
# ### MY CODE WILL ADD TWO NUMBERS AND PRINT'S ITS RESULT.

# %%
x=int(input("enter the integer:"))
y=int(input("enter the integer:"))
print(x+y)
